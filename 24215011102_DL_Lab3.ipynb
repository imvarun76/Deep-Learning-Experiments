# %% [markdown]
# NAME - VARUN MISHRA
#
# SCHOLAR NO - 2421501102

# %% [markdown]
# 1. Demonstrate the behavior of Gradient Descent and its variants —Batch Gradient Descent (GD), Stochastic Gradient Descent
# (SGD), and Mini-batch Stochastic Gradient Descent (Mini-batch
# SGD) on both simple and complex functions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define functions
def f(x):
    return x**2

def G(x):
    return x*4 + x3 + x*2

# Define gradients
def grad_f(x):
    return 2*x

def grad_G(x):
    return 4*(x*3) + 3*(x**2) + 2*x

# Parameters
learning_rate = 0.001
epochs = 50
x_range = np.arange(-20, 21)

# Gradient Descent (GD)
def gd(func, grad_func, x0, learning_rate, epochs):
    x = x0
    trajectory = [x0]
    for _ in range(epochs):
        x = x - learning_rate * grad_func(x)
        trajectory.append(x)
    return x, trajectory

# Stochastic Gradient Descent (SGD)
def sgd(func, grad_func, x0, learning_rate, epochs):
    x = x0
    trajectory = [x0]
    for _ in range(epochs):
        noisy_grad = grad_func(x) + np.random.normal(0, 1)
        x = x - learning_rate * noisy_grad
        trajectory.append(x)
    return x, trajectory

# Mini-batch Stochastic Gradient Descent (Mini-batch SGD)
def minibatch_sgd(func, grad_func, x0, learning_rate, epochs, batch_size=5):
    x = x0
    trajectory = [x0]
    for _ in range(epochs):
        noisy_grad = grad_func(x) + np.random.normal(0, 0.5)
        x = x - learning_rate * noisy_grad
        trajectory.append(x)
    return x, trajectory

# Run optimization algorithms
x0 = 10

# For f(x) = x^2
x_gd_f, gd_trajectory_f = gd(f, grad_f, x0, learning_rate, epochs)
x_sgd_f, sgd_trajectory_f = sgd(f, grad_f, x0, learning_rate, epochs)
x_mbsgd_f, mbsgd_trajectory_f = minibatch_sgd(f, grad_f, x0, learning_rate, epochs)

# For G(x) = x^4 + x^3 + x^2
x_gd_G, gd_trajectory_G = gd(G, grad_G, x0, learning_rate, epochs)
x_sgd_G, sgd_trajectory_G = sgd(G, grad_G, x0, learning_rate, epochs)
x_mbsgd_G, mbsgd_trajectory_G = minibatch_sgd(G, grad_G, x0, learning_rate, epochs)

# Plotting Trajectories
plt.figure(figsize=(15, 10))

# f(x) = x^2
plt.subplot(2, 3, 1)
plt.plot(gd_trajectory_f, label='GD', marker='o',color='red')
plt.title('GD Trajectory for f(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

plt.subplot(2, 3, 2)
plt.plot(sgd_trajectory_f, label='SGD', marker='x',color='blue')
plt.title('SGD Trajectory for f(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

plt.subplot(2, 3, 3)
plt.plot(mbsgd_trajectory_f, label='Mini-batch SGD', marker='s',color='green')
plt.title('Mini-batch SGD Trajectory for f(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

# G(x) = x^4 + x^3 + x^2
plt.subplot(2, 3, 4)
plt.plot(gd_trajectory_G, label='GD', marker='o',color='red')
plt.title('GD Trajectory for G(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

plt.subplot(2, 3, 5)
plt.plot(sgd_trajectory_G, label='SGD', marker='x',color='blue')
plt.title('SGD Trajectory for G(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

plt.subplot(2, 3, 6)
plt.plot(mbsgd_trajectory_G, label='Mini-batch SGD', marker='s',color='green')
plt.title('Mini-batch SGD Trajectory for G(x)')
plt.xlabel('Iterations')
plt.ylabel('x')
plt.legend()

plt.tight_layout()
plt.show()

# Print optimal values
print(f"Optimal x for f(x) using GD: {x_gd_f}")
print(f"Optimal x for f(x) using SGD: {x_sgd_f}")
print(f"Optimal x for f(x) using Mini-batch SGD: {x_mbsgd_f}")

print(f"Optimal x for G(x) using GD: {x_gd_G}")
print(f"Optimal x for G(x) using SGD: {x_sgd_G}")
print(f"Optimal x for G(x) using Mini-batch SGD: {x_mbsgd_G}")
# Out:
# Optimal x for f(x) using GD: 9.047468180040356
# Optimal x for f(x) using SGD: 9.047534296196307
# Optimal x for f(x) using Mini-batch SGD: 9.048732966890253
# Optimal x for G(x) using GD: 2.3336055685431147
# Optimal x for G(x) using SGD: 2.335028542247342
# Optimal x for G(x) using Mini-batch SGD: 2.3317271982669574

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its gradient
def f(x):
    return np.cos(np.pi * x)

def grad_f(x):
    return -np.pi * np.sin(np.pi * x)

# Parameters
x0 = 1
eta = 0.1
num_iterations = 50

# Gradient Descent (GD)
x_gd = x0
gd_trajectory = [x_gd]
for _ in range(num_iterations):
    x_gd = x_gd - eta * grad_f(x_gd)
    gd_trajectory.append(x_gd)

# Stochastic Gradient Descent (SGD)
x_sgd = x0
sgd_trajectory = [x_sgd]
for _ in range(num_iterations):
    # Adding some noise to simulate SGD
    noisy_grad = grad_f(x_sgd) + np.random.normal(0, 1)
    x_sgd = x_sgd - eta * noisy_grad
    sgd_trajectory.append(x_sgd)

# Mini-batch Stochastic Gradient Descent (Mini-batch SGD)
x_mbsgd = x0
mbsgd_trajectory = [x_mbsgd]
batch_size = 5
for _ in range(num_iterations):
    # Adding less noise to simulate mini-batch SGD
    noisy_grad = grad_f(x_mbsgd) + np.random.normal(0, 0.5)
    x_mbsgd = x_mbsgd - eta * noisy_grad
    mbsgd_trajectory.append(x_mbsgd)

# Plotting the trajectories in separate graphs
plt.figure(figsize=(15, 5))

# Gradient Descent (GD)
plt.subplot(1, 3, 1)
plt.plot(gd_trajectory, label='Gradient Descent (GD)', marker='o', color='blue')
plt.axhline(0, color='black', linestyle='--', label='Optimal Solution (x=0)')
plt.xlabel('Iteration')
plt.ylabel('x value')
plt.title('Gradient Descent (GD) Trajectory')
plt.legend()
plt.grid(True)

# Stochastic Gradient Descent (SGD)
plt.subplot(1, 3, 2)
plt.plot(sgd_trajectory, label='Stochastic Gradient Descent (SGD)', marker='x', color='green')
plt.axhline(0, color='black', linestyle='--', label='Optimal Solution (x=0)')
plt.xlabel('Iteration')
plt.ylabel('x value')
plt.title('Stochastic Gradient Descent (SGD) Trajectory')
plt.legend()
plt.grid(True)

# Mini-batch Stochastic Gradient Descent (Mini-batch SGD)
plt.subplot(1, 3, 3)
plt.plot(mbsgd_trajectory, label='Mini-batch SGD', marker='s', color='red')
plt.axhline(0, color='black', linestyle='--', label='Optimal Solution (x=0)')
plt.xlabel('Iteration')
plt.ylabel('x value')
plt.title('Mini-batch SGD Trajectory')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Consider this function also cos(pi.x) compute for x -4 to 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the functions and their gradients
def f(x):
    return x**2

def f_prime(x):
    return 2*x

def G(x):
    return x**4 + x**3 + x**2

def G_prime(x):
    return 4*x**3 + 3*x**2 + 2*x

def H(x):
    return np.cos(np.pi * x)

def H_prime(x):
    return -np.pi * np.sin(np.pi * x)

# Gradient Descent (GD) algorithm
def gradient_descent(learning_rate, epochs, func_prime, x_init, batch_size=None):
    x = x_init
    x_values = [x]
    for _ in range(epochs):
        if batch_size is None:  # Batch Gradient Descent (GD)
            grad = func_prime(x)
            x -= learning_rate * grad
        else:  # Mini-batch SGD
            x_batch = np.random.uniform(-10, 10, batch_size)  # Simulating data points
            grad = np.mean([func_prime(xi) for xi in x_batch])
            x -= learning_rate * grad
        x = np.clip(x, -10, 10)  # Clamp to avoid overflow
        x_values.append(x)
    return np.array(x_values)

# Stochastic Gradient Descent (SGD)
def stochastic_gradient_descent(learning_rate, epochs, func_prime, x_init):
    x = x_init
    x_values = [x]
    for _ in range(epochs):
        x_rand = np.random.uniform(-10, 10)
        grad = func_prime(x_rand)
        x -= learning_rate * grad
        x = np.clip(x, -10, 10)
        x_values.append(x)
    return np.array(x_values)

# Parameters
learning_rate = 0.01
epochs = 50
x_init = 5

# Generate data for Batch GD, SGD, and Mini-batch SGD on H(x) = cos(pi*x)
x_values_batch_H = gradient_descent(learning_rate, epochs, H_prime, x_init)
x_values_sgd_H = stochastic_gradient_descent(learning_rate, epochs, H_prime, x_init)
x_values_minibatch_H = gradient_descent(learning_rate, epochs, H_prime, x_init, batch_size=10)

# Generate a range of x-values for plotting the function and gradients
x_range = np.linspace(-10, 10, 400)

# Plot for H(x) = cos(pi*x)
plt.figure(figsize=(15, 5))

# Batch GD
plt.subplot(1, 3, 1)
plt.plot(x_range, H(x_range), label='H(x) = cos(pi*x)', color='black')
plt.scatter(x_values_batch_H, H(x_values_batch_H), color='blue', label='Batch GD')
plt.scatter(x_values_batch_H[-1], H(x_values_batch_H[-1]), color='cyan', label='Optimum')
plt.title("Batch GD for H(x) = cos(pi*x)")
plt.xlabel("x")
plt.ylabel("H(x)")
plt.legend()

# SGD
plt.subplot(1, 3, 2)
plt.plot(x_range, H(x_range), label='H(x) = cos(pi*x)', color='black')
plt.scatter(x_values_sgd_H, H(x_values_sgd_H), color='red', label='SGD')
plt.scatter(x_values_sgd_H[-1], H(x_values_sgd_H[-1]), color='orange', label='Optimum')
plt.title("SGD for H(x) = cos(pi*x)")
plt.xlabel("x")
plt.ylabel("H(x)")
plt.legend()

# Mini-batch GD
plt.subplot(1, 3, 3)
plt.plot(x_range, H(x_range), label='H(x) = cos(pi*x)', color='black')
plt.scatter(x_values_minibatch_H, H(x_values_minibatch_H), color='green', label='Mini-batch GD')
plt.scatter(x_values_minibatch_H[-1], H(x_values_minibatch_H[-1]), color='lime', label='Optimum')
plt.title("Mini-batch GD for H(x) = cos(pi*x)")
plt.xlabel("x")
plt.ylabel("H(x)")
plt.legend()

plt.tight_layout()
plt.show()

print(f"Batch GD Optimum for H(x): x = {x_values_batch_H[-1]}, H(x) = {H(x_values_batch_H[-1])}")
print(f"SGD Optimum for H(x): x = {x_values_sgd_H[-1]}, H(x) = {H(x_values_sgd_H[-1])}")
print(f"Mini-batch GD Optimum for H(x): x = {x_values_minibatch_H[-1]}, H(x) = {H(x_values_minibatch_H[-1])}")
# Out:
# Batch GD Optimum for H(x): x = 5.0, H(x) = -1.0
# SGD Optimum for H(x): x = 5.110260604559943, H(x) = -0.9406031243884228
# Mini-batch GD Optimum for H(x): x = 5.016757749277543, H(x) = -0.9986145182275576

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return np.cos(np.pi * x)

def df(x):
    return -2 * np.pi * np.sin(np.pi * x)

# Gradient Descent (GD) algorithm
def gradient_descent(learning_rate, epochs, func_prime, x_init, batch_size=None):
    x = x_init
    x_values = [x]
    for _ in range(epochs):
        if batch_size is None:  # Batch Gradient Descent (GD)
            grad = func_prime(x)
            x -= learning_rate * grad
        else:  # Mini-batch SGD
            # Randomly sample batch of size `batch_size`
            x_batch = np.random.uniform(-4, 4, batch_size)  # Simulating data points in the range [-4, 4]
            grad = np.mean([func_prime(xi) for xi in x_batch])  # Mean gradient over mini-batch
            x -= learning_rate * grad
        # Clamp x to avoid overflow (limit the range)
        x = np.clip(x, -4, 4)  # Clamping between -4 and 4
        x_values.append(x)
    return np.array(x_values)

# Stochastic Gradient Descent (SGD)
def stochastic_gradient_descent(learning_rate, epochs, func_prime, x_init):
    x = x_init
    x_values = [x]
    for _ in range(epochs):
        # For SGD, we take the gradient at a random point
        x_rand = np.random.uniform(-4, 4)  # Random point from range [-4, 4]
        grad = func_prime(x_rand)
        x -= learning_rate * grad
        # Clamp x to avoid overflow (limit the range)
        x = np.clip(x, -4, 4)  # Clamping between -4 and 4
        x_values.append(x)
    return np.array(x_values)

# Parameters
learning_rate = 0.01  # You can adjust the learning rate if needed
epochs = 50
x_init = 1  # Starting point for optimization

# Generate data for Batch GD, SGD, and Mini-batch SGD on f(x) = cos(pi * x)
x_values_batch_f = gradient_descent(learning_rate, epochs, df, x_init)
x_values_sgd_f = stochastic_gradient_descent(learning_rate, epochs, df, x_init)
x_values_minibatch_f = gradient_descent(learning_rate, epochs, df, x_init, batch_size=10)

# Generate a range of x-values for plotting the function curve
x_range = np.linspace(-4, 4, 400)

# Plotting the actual function curve and gradient descent trajectories
plt.figure(figsize=(14, 7))

# Plot for f(x) = cos(pi * x)
plt.plot(x_range, f(x_range), label='f(x) = cos(pi * x)', color='black')  # Function curve
plt.plot(x_values_batch_f, f(x_values_batch_f), 'bo-', label='Batch GD')  # Trajectory of GD
plt.plot(x_values_sgd_f, f(x_values_sgd_f), 'ro-', label='SGD')  # Trajectory of SGD
plt.plot(x_values_minibatch_f, f(x_values_minibatch_f), 'go-', label='Mini-batch SGD')  # Trajectory of Mini-batch SGD
plt.title("Convergence for f(x) = cos(pi * x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()

plt.tight_layout()
plt.show()

# Return the optimal final values for f(x)
final_x_batch_f = x_values_batch_f[-1]
final_x_sgd_f = x_values_sgd_f[-1]
final_x_minibatch_f = x_values_minibatch_f[-1]

(final_x_batch_f, final_x_sgd_f, final_x_minibatch_f)
# Out:
# (np.float64(1.0),
#  np.float64(1.0486204051659804),
#  np.float64(1.086645327484645))

# %% [markdown]
# 3. Develop and train a deep neural network to predict the onset of
# diabetes using the Pima Indians Diabetes dataset.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    roc_curve,
    classification_report,
)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from imblearn.over_sampling import SMOTE  # For handling class imbalance

# Step 1: Load the dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
column_names = [
    "Pregnancies",
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age",
    "Outcome",
]
data = pd.read_csv(url, names=column_names)

# Step 2: Data Exploration
print("Dataset Head:")
print(data.head())

print("\nDataset Info:")
print(data.info())

print("\nDataset Description:")
print(data.describe())

# Check for missing values (encoded as 0 in this dataset)
print("\nMissing Values (encoded as 0):")
print((data == 0).sum())

# Visualize the distribution of the target variable
plt.figure(figsize=(6, 4))
sns.countplot(x="Outcome", data=data)
plt.title("Distribution of Diabetes Outcomes")
plt.show()

# Step 3: Data Preprocessing
# Handle missing values (replace 0s with NaN and then impute)
data[["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]] = data[
    ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
].replace(0, np.nan)
data.fillna(data.median(), inplace=True)

# Check for class imbalance
print("\nClass Distribution:")
print(data["Outcome"].value_counts())

# Apply SMOTE to handle class imbalance
X = data.drop("Outcome", axis=1)
y = data["Outcome"]
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42
)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 4: Build the Deep Neural Network
model = Sequential(
    [
        Dense(64, activation="relu", input_shape=(X_train.shape[1],)),  # Input layer
        Dropout(0.2),  # Dropout for regularization
        Dense(32, activation="relu"),  # Hidden layer
        Dropout(0.2),  # Dropout for regularization
        Dense(16, activation="relu"),  # Hidden layer
        Dense(1, activation="sigmoid"),  # Output layer (binary classification)
    ]
)

# Compile the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Step 5: Train the Model
early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1,
)

# Step 6: Evaluate the Model
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Evaluate on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict(X_test))
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="ROC Curve")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# ROC-AUC Score
roc_auc = roc_auc_score(y_test, model.predict(X_test))
print(f"\nROC-AUC Score: {roc_auc:.2f}")

# Step 7: Interpretation
# Model Performance Summary
print("\nModel Performance Summary:")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print(f"Precision: {precision_score(y_test, y_pred):.2f}")
print(f"Recall: {recall_score(y_test, y_pred):.2f}")
print(f"F1-Score: {f1_score(y_test, y_pred):.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")

# Handling Class Imbalance Impact
print("\nHandling Class Imbalance Impact:")
print("1. SMOTE was used to address class imbalance by oversampling the minority class.")
print("2. This improved the model's ability to predict both classes (diabetic and non-diabetic).")
print("3. The F1-score and ROC-AUC score reflect balanced performance across classes.")
# Out:
# Dataset Head:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
# ...
